# %%
# !pkill -f streamlit
# !pkill -f ollama
# !pkill -f ngrok

# %%
# !pip install streamlit fitz langchain langchain-community tools
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 124.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 100.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 121.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 109.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.4/95.4 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.9/425.9 kB 39.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.1/565.1 kB 52.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 107.9 MB/s eta 0:00:00
# ...

# %%
# !pip install -U ollama langchain-ollama pyngrok

# %%
# ===== 1. Setup System & Dependencies =====
# !sudo apt update -y
# !sudo apt install -y tesseract-ocr libgl1 libglib2.0-0

# !git clone https://github.com/Smruticodes/chat-with-docs
# %cd /content/chat-with-docs

# !pip install -r requirements.txt
# !pip install -U ollama langchain-ollama pyngrok python-docx python-pptx pytesseract

# ===== 2. Install Ollama =====
# !curl -fsSL https://ollama.com/install.sh | sh

# ===== 3. Start Ollama =====
# !OLLAMA_HOST=0.0.0.0:11434 nohup ollama serve > /content/ollama.log 2>&1 &

import time
print("⏳ Waiting for Ollama to start...")
time.sleep(5)
# !tail -n 20 /content/ollama.log

# Pull required models
# !ollama pull mxbai-embed-large
# !ollama pull llama3.2

# ===== 4. Kill any old Streamlit/ngrok processes =====
# !pkill -f streamlit || true
# !pkill -f ngrok || true

# ===== 5. Start Streamlit in background =====
import os
os.environ["OLLAMA_HOST"] = "http://127.0.0.1:11434"

# !nohup streamlit run app.py --server.address 0.0.0.0 --server.port 8501 > /content/streamlit.log 2>&1 &

# ===== 6. Wait for Streamlit to start =====
import time
for i in range(20):
    time.sleep(2)
    if "External URL" in open("/content/streamlit.log").read():
        break
else:
    print("⚠️ Streamlit did not start, showing logs:")
    # !tail -n 50 /content/streamlit.log

# ===== 7. Create ngrok tunnel =====
from pyngrok import ngrok
ngrok.set_auth_token("replace with your ngrok token")  # Replace with your token
public_url = ngrok.connect(8501)
print("✅ Your app is live here:", public_url)
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,923 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...
